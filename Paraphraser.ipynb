# %%
# !pip install --upgrade pip
# !pip install transformers
# !pip install sentencepiece
# !pip install transformers[sentencepiece]
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/a4/6d/6463d49a933f547439d6b5b98b46af8742cc03ae83543e4d7688c2420f8b/pip-21.3.1-py3-none-any.whl (1.7MB)
# Installing collected packages: pip
#   Found existing installation: pip 19.1.1
#     Uninstalling pip-19.1.1:
#       Successfully uninstalled pip-19.1.1
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\Dell\\AppData\\Local\\Temp\\pip-uninstall-aid3lwr4\\pip.exe'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: transformers in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (4.11.3)
# Requirement already satisfied: huggingface-hub>=0.0.17 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (0.0.19)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (2.26.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (2021.8.28)
# Requirement already satisfied: importlib-metadata in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (4.8.1)
# Requirement already satisfied: filelock in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (3.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (21.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (0.10.3)
# Requirement already satisfied: sacremoses in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (0.0.46)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers) (1.21.2)
# Requirement already satisfied: typing-extensions in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from huggingface-hub>=0.0.17->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from tqdm>=4.27->transformers) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: click in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from sacremoses->transformers) (8.0.1)
# Requirement already satisfied: joblib in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from sacremoses->transformers) (1.11.0)
# Requirement already satisfied: sentencepiece in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (0.1.96)
# Requirement already satisfied: transformers[sentencepiece] in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (4.11.3)
# Requirement already satisfied: huggingface-hub>=0.0.17 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (0.0.19)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (1.21.2)
# Requirement already satisfied: filelock in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (3.3.1)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (2.26.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (2021.8.28)
# Requirement already satisfied: sacremoses in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (0.0.46)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (21.0)
# Requirement already satisfied: importlib-metadata in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (4.8.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (6.0)
# Requirement already satisfied: protobuf in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (3.19.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from transformers[sentencepiece]) (0.1.96)
# Requirement already satisfied: typing-extensions in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from huggingface-hub>=0.0.17->transformers[sentencepiece]) (3.10.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from packaging>=20.0->transformers[sentencepiece]) (2.4.7)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from tqdm>=4.27->transformers[sentencepiece]) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from importlib-metadata->transformers[sentencepiece]) (3.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from requests->transformers[sentencepiece]) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from requests->transformers[sentencepiece]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from requests->transformers[sentencepiece]) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from requests->transformers[sentencepiece]) (2021.10.8)
# Requirement already satisfied: click in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from sacremoses->transformers[sentencepiece]) (8.0.1)
# Requirement already satisfied: six in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from sacremoses->transformers[sentencepiece]) (1.11.0)
# Requirement already satisfied: joblib in c:\users\dell\appdata\local\programs\python\python37-32\lib\site-packages (from sacremoses->transformers[sentencepiece]) (1.0.1)

# %%
# !pip3 install torch torchvision

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
tokenizer = AutoTokenizer.from_pretrained("Vamsi/T5_Paraphrase_Paws")  
model = AutoModelForSeq2SeqLM.from_pretrained("Vamsi/T5_Paraphrase_Paws")
# Out:
# Downloading:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2217: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
s = "okay bitch???? have you forgotten who owns this account????"
text =  "paraphrase: " + s + " </s>"

encoding = tokenizer.encode_plus(text,padding='max_length', return_tensors="pt")
input_ids, attention_masks = encoding["input_ids"], encoding["attention_mask"]
outputs = model.generate(
    input_ids=input_ids, attention_mask=attention_masks,
    max_length=256,
    do_sample=True,
    top_k=120,
    top_p=0.95,
    early_stopping=True,
    num_return_sequences=15
)
for output in outputs:
    line = tokenizer.decode(output, skip_special_tokens=True,clean_up_tokenization_spaces=True)
    print(line)
# Out:
# Bitch, have you forgotten who holds this account?
# OK bitch? Have you forgotten who owns this account??
# Has anyone forgotten who owns this account?
# Okay bitch???? Have you forgotten who owns this account?
# Okay bitch???? Have you forgotten who owns this account????
# Have you forgotten who owns this account?
# Okay, but have you forgotten who owns this account?
# Bitch, have you forgotten who owns this account?
# have you forgot who owned this account???? Okay bitch!
# Bitch???? Have you forgotten who owns this account????
# Bitch have you forgotten who holds this account????
# Have you forgotten who owns this account????
# Ok, bitch, have you forgotten who owns this account????
# Okay bitch? Have you forgotten who holds this account????
# Ok bitch, have you forgotten who is owning this account????
