# %% [markdown]
# # Setting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install tweet-preprocessor
# Out:
# Collecting transformers
#   Downloading transformers-4.12.2-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 5.3 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Collecting huggingface-hub>=0.0.17
#   Downloading huggingface_hub-0.0.19-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.1)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 44.0 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.3.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 40.1 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 39.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.17->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.19 pyyaml-6.0 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.12.2
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.2 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96
# Collecting tweet-preprocessor
#   Downloading tweet_preprocessor-0.6.0-py3-none-any.whl (27 kB)
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0

# %%
import torch
from keras.preprocessing.sequence import pad_sequences
from transformers import XLNetTokenizer
from nltk import tokenize
import numpy as np
import preprocessor as p
import nltk
nltk.download('punkt')
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import XLNetForSequenceClassification
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import torch.nn.functional as F

# %%
BATCH_SIZE = 32
MAX_LENGTH = 120
XLNET_MODEL = 'xlnet-base-cased'
FILE_PATH = '/content/drive/MyDrive/1027/'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Load Model

# %%
tokenizer = XLNetTokenizer.from_pretrained(XLNET_MODEL, do_lower_case=True)
#model = torch.load('/content/drive/MyDrive/Colab Notebooks/classifier.pt',map_location=torch.device('cpu'))
#model = torch.load(FILE_PATH + 'classifier.pt')
model = XLNetForSequenceClassification.from_pretrained(XLNET_MODEL, num_labels=2)
model.load_state_dict(torch.load(FILE_PATH + 'model_v2_955.pt'))
# Out:
# Some weights of the model checkpoint at xlnet-base-cased were not used when initializing XLNetForSequenceClassification: ['lm_loss.weight', 'lm_loss.bias']
# - This IS expected if you are initializing XLNetForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLNetForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLNetForSequenceClassification were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['sequence_summary.summary.bias', 'logits_proj.bias', 'sequence_summary.summary.weight', 'logits_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <All keys matched successfully>

# %%
model.to(device)
# Out:
# XLNetForSequenceClassification(
#   (transformer): XLNetModel(
#     (word_embedding): Embedding(32000, 768)
#     (layer): ModuleList(
#       (0): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (3): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (4): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (5): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (6): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (7): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (8): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (9): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (10): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (11): XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (sequence_summary): SequenceSummary(
#     (summary): Linear(in_features=768, out_features=768, bias=True)
#     (first_dropout): Identity()
#     (last_dropout): Dropout(p=0.1, inplace=False)
#   )
#   (logits_proj): Linear(in_features=768, out_features=2, bias=True)
# )

# %% [markdown]
# # Predict

# %%
def process(tweets,add_special_token=True):
  p.set_options(p.OPT.URL, p.OPT.EMOJI, p.OPT.MENTION) # tweet-preprocessor
  
  new_tweets = []
  for tweet in tweets:
    tweet = p.clean(tweet)
    sentences = tokenize.sent_tokenize(tweet)
    if add_special_token:
        tweet_with_token = ' [SEP]'.join(sentences) + ' [SEP] [CLS]'
        new_tweets.append(tweet_with_token)
    else:
        new_tweets.append(tweet)

  return new_tweets


def get_model_data(tokenizer, tweets, labels , maxlen, batch_size, add_special_token = True):
    
    if add_special_token:
        tweets = process(tweets)
    
    #tokenizer = XLNetTokenizer.from_pretrained(XLNET_MODEL, do_lower_case=True)
    
    tokenized_tweets = [tokenizer.tokenize(tweet) for tweet in tweets]
    # Use the XLNet tokenizer to convert the tokens to their index numbers in the XLNet vocabulary
    input_ids = [tokenizer.convert_tokens_to_ids(t) for t in tokenized_tweets]
    # Pad our input tokens
    input_ids = pad_sequences(input_ids, maxlen= maxlen, dtype="long", truncating="post", padding="post")
    
    # Create attention masks
    attention_masks = []
    
    # Create a mask of 1s for each token followed by 0s for padding
    for seq in input_ids:
      seq_mask = [float(i>0) for i in seq]
      attention_masks.append(seq_mask)
      
    # Convert all of our data into torch tensors, the required datatype for our model
    inputs = torch.tensor(input_ids)
    masks = torch.tensor(attention_masks)
    labels = torch.tensor(labels)
    
    # Create an iterator of our data with torch DataLoader. This helps save on memory during training because, unlike a for loop, 
    # with an iterator the entire dataset does not need to be loaded into memory
    data = TensorDataset(inputs, masks, labels)
    sampler = SequentialSampler(data)
    dataloader = DataLoader(data, sampler=sampler, batch_size=batch_size)
    
    return data, sampler, dataloader

def predict(model, tokenizer, tweets,labels,maxlen = MAX_LENGTH, batch_size = BATCH_SIZE):


  prediction_data, prediction_sampler, prediction_dataloader = get_model_data(tokenizer, tweets, labels , maxlen, batch_size, add_special_token = True)

  # Tracking variables 
  predictions , true_labels = [], []
  prob_list = []

  # Predict 
  for batch in prediction_dataloader:
    # Add batch to GPU
    batch = tuple(t.to(device) for t in batch)
    # Unpack the inputs from our dataloader
    b_input_ids, b_input_mask, b_labels = batch
    # Telling the model not to compute or store gradients, saving memory and speeding up prediction
    with torch.no_grad():
      # Forward pass, calculate logit predictions
      outputs = model(b_input_ids, b_input_mask)
      logits = outputs[0]
      #outputs = outputs[0][0].cpu().detach()
      #_, prediction = torch.max(outputs, dim =-1)
      result = outputs[0][0].cpu().detach()
      probs = F.softmax(result, dim=-1).cpu().detach().numpy().tolist()
      _, prediction = torch.max(result, dim =-1)

    # Move logits and labels to CPU
    #logits = logits.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()

     
    # Store predictions and true labels
    predictions.append(prediction)
    prob_list.append(probs)
    true_labels.append(label_ids)

    return predictions , prob_list

# %% [markdown]
# # Load Dataset

# %%
def get_tsa():
    
    path = 'data/Sentiment-Analysis-Dataset/Sentiment Analysis Dataset.csv'
    with open(path,'rb') as file:
        lines = file.readlines()
        #header = lines[0].decode('utf-8').rstrip().split(',')
        header = lines[0].rstrip().decode('utf-8').split(',')
        data_list = []
        for line in lines[1:]:
            line = line.rstrip()
            props = line.decode('utf-8').split(',')
            if len(props) > 4:
                sentiment_text = ','.join(props[3:]).strip('"')
                data = props[:3]
                data.append(sentiment_text)
            else:
                data = props
            data_list.append(data)
            # test index = 4286
    df = pd.DataFrame(data_list, columns = header)
    return df

# %%
import torch.nn.functional as F
txts = ['I am so happy']
labels = [1]
predictions , prob_list = predict(model, tokenizer, txts,labels,maxlen = MAX_LENGTH, batch_size = BATCH_SIZE)

# %%
predictions
# Out:
# [tensor(1)]

# %%
prob_list
# Out:
# [[0.0042115263640880585, 0.9957885146141052]]

# %% [markdown]
#     print("Positive score:", probs[1])
#     print("Negative score:", probs[0])

# %%
outputs = outputs[0][0].cpu().detach()

    probs = F.softmax(outputs, dim=-1).cpu().detach().numpy().tolist()
    _, prediction = torch.max(outputs, dim =-1)
# Out:
#   File "<ipython-input-17-f964521fa30b>", line 3
#     probs = F.softmax(outputs, dim=-1).cpu().detach().numpy().tolist()
#     ^
# IndentationError: unexpected indent

# %%
outputs = outputs[0][0].cpu().detach()
_, prediction = torch.max(outputs, dim =-1)

# %%
def predict_sentiment(text):
    review_text = text

    encoded_review = tokenizer.encode_plus(
    review_text,
    max_length=MAX_LENGTH,
    add_special_tokens=True,
    return_token_type_ids=False,
    pad_to_max_length=False,
    return_attention_mask=True,
    return_tensors='pt',
    )

    input_ids = pad_sequences(encoded_review['input_ids'], maxlen=MAX_LENGTH, dtype=torch.Tensor ,truncating="post",padding="post")
    input_ids = input_ids.astype(dtype = 'int64')
    input_ids = torch.tensor(input_ids) 

    attention_mask = pad_sequences(encoded_review['attention_mask'], maxlen=MAX_LENGTH, dtype=torch.Tensor ,truncating="post",padding="post")
    attention_mask = attention_mask.astype(dtype = 'int64')
    attention_mask = torch.tensor(attention_mask) 

    input_ids = input_ids.reshape(1,120).to(device)
    attention_mask = attention_mask.to(device)

    outputs = model(input_ids=input_ids, attention_mask=attention_mask)

    outputs = outputs[0][0].cpu().detach()

    probs = F.softmax(outputs, dim=-1).cpu().detach().numpy().tolist()
    _, prediction = torch.max(outputs, dim =-1)

    return probs[1], probs[0]

    print("Positive score:", probs[1])
    print("Negative score:", probs[0])
    print(f'Review text: {review_text}')
    #print(f'Sentiment  : {class_names[prediction]}')

# %%
import torch.nn.functional as F
text = 'I am so happy'
#labels = [1]
predict_sentiment(text)
# Out:
# Positive score: 0.9979650974273682
# Negative score: 0.002034929348155856
# Review text: I am so happy

# %%
predict_sentiment('I feel sad')
# Out:
# Positive score: 0.004747556056827307
# Negative score: 0.9952524900436401
# Review text: I feel sad

# %%
predict_sentiment('@blackhitop all i can say is wow!!! beautiful as always. have an awesome week!!!,tsinspired')
# Out:
# Positive score: 0.9974767565727234
# Negative score: 0.002523185219615698
# Review text: @blackhitop all i can say is wow!!! beautiful as always. have an awesome week!!!,tsinspired

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
rephraser_tokenizer = AutoTokenizer.from_pretrained("Vamsi/T5_Paraphrase_Paws")  
rephraser_model = AutoModelForSeq2SeqLM.from_pretrained("Vamsi/T5_Paraphrase_Paws")
# Out:
# Downloading:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]

# %%
def get_rephrased(tokenizer, model, text):
  encoding = tokenizer.encode_plus(text,padding='max_length', return_tensors="pt")
  input_ids, attention_masks = encoding["input_ids"], encoding["attention_mask"]
  outputs = model.generate(
      input_ids=input_ids, attention_mask=attention_masks,
      max_length=256,
      do_sample=True,
      top_k=120,
      top_p=0.95,
      early_stopping=True,
      num_return_sequences=15
  )
  lines = []
  for output in outputs:
      line = tokenizer.decode(output, skip_special_tokens=True,clean_up_tokenization_spaces=True)
      lines.append(line)
  return lines

# %%
s = 'fucking embarrassing. this team needs to get its fucking shit together. goddammit.'
text =  "paraphrase: " + s + " </s>"

result = get_rephrased(rephraser_tokenizer, rephraser_model, text)
print(result)
# Out:
# ['This team needs to get his fucking shit together.', 'The team needs to get its fucking shit together.  Thanks everyone!', '... This team needs to get the Fucking Sick together.', 'This team needs to strut it together.', 'The fucking is embarrassing... this team needs to get their fucking shit together, goddammit!', 'This team must get its fucked shit together.', 'Fucking embarrassing: this team has to get together his fucking shit.', 'This team needs to get its fucking shit together.', 'The team needs to get together a cracking smack to get to it.', 'This team needs to bring their fucking shit together!', 'Those are embarrassing. This team needs to put its fucking shit together.', 'Fucking is embarrassing. This team needs to get the Fucking Shit together. Gotta do this.', 'This team needs to get its fucking shit together. goddammit.', 'fucking embarrassing. this team needs to get together her fucking shits', 'This team needs to get its fucking shit together. goddammit.']

# %%
for r in result:
  print(predict_sentiment(r))
# Out:
# Positive score: 0.0022140678483992815
# Negative score: 0.9977859258651733
# Review text: This team needs to get his fucking shit together.
# None
# Positive score: 0.010424972511827946
# Negative score: 0.9895750880241394
# Review text: The team needs to get its fucking shit together.  Thanks everyone!
# None
# Positive score: 0.0011630168883129954
# Negative score: 0.9988370537757874
# Review text: ... This team needs to get the Fucking Sick together.
# None
# Positive score: 0.9426029324531555
# Negative score: 0.05739705264568329
# Review text: This team needs to strut it together.
# None
# Positive score: 0.0015606119995936751
# Negative score: 0.998439371585846
# Review text: The fucking is embarrassing... this team needs to get their fucking shit together, goddammit!
# None
# Positive score: 0.0011853836476802826
# Negative score: 0.998814582824707
# Review text: This team must get its fucked shit together.
# None
# Positive score: 0.0010946408146992326
# Negative score: 0.9989053010940552
# Review text: Fucking embarrassing: this team has to get together his fucking shit.
# None
# Positive score: 0.0029539959505200386
# Negative score: 0.9970460534095764
# Review text: This team needs to get its fucking shit together.
# None
# Positive score: 0.9317619204521179
# Negative score: 0.06823810189962387
# Review text: The team needs to get together a cracking smack to get to it.
# None
# Positive score: 0.0032741508912295103
# Negative score: 0.9967257976531982
# Review text: This team needs to bring their fucking shit together!
# None
# Positive score: 0.005375185515731573
# Negative score: 0.9946247935295105
# Review text: Those are embarrassing. This team needs to put its fucking shit together.
# None
# Positive score: 0.0038492372259497643
# Negative score: 0.9961507320404053
# Review text: Fucking is embarrassing. This team needs to get the Fucking Shit together. Gotta do this.
# None
# Positive score: 0.003397806780412793
# Negative score: 0.9966021776199341
# Review text: This team needs to get its fucking shit together. goddammit.
# None
# Positive score: 0.002211378887295723
# Negative score: 0.9977885484695435
# Review text: fucking embarrassing. this team needs to get together her fucking shits
# None
# Positive score: 0.003397806780412793
# Negative score: 0.9966021776199341
# Review text: This team needs to get its fucking shit together. goddammit.
# None

# %% [markdown]
# # Result

# %% [markdown]
# ## Load Data

# %%
def get_opt(path, pess_threshold = -1, opt_threshold = 1):    
    #path = 'data/tweets_annotation.csv'
    df = pd.read_csv(path)
  
    if pess_threshold == opt_threshold:
      conditions = [
        (df['AverageAnnotation'] <= pess_threshold),
        (df['AverageAnnotation'] > opt_threshold)
      ]
      values = ['pessimistic','optimistic']
      target =[0,1]
    elif pess_threshold < opt_threshold:
      conditions = [
        (df['AverageAnnotation'] >= opt_threshold),
        (df['AverageAnnotation'] <= pess_threshold),
        (df['AverageAnnotation'] < opt_threshold) & (df['AverageAnnotation'] > pess_threshold)
      ]
      values = ['optimistic','pessimistic','neutral']
      target = [1,0,None]
    else:
      print('The pessimistic error is greater than optimistic threshold')
      return
    
    df['Label'] = np.select(conditions,values)
    df['Target'] = np.select(conditions,target)  
    filtered_df = df.loc[(df['Label'] != 'neutral'),df.columns]
    filtered_df.astype({'Target': 'int32'}).dtypes
    filtered_df = filtered_df.reset_index(drop=True)
  
    return filtered_df

# %%
def get_tsa(path):
    
    #path = 'data/Sentiment-Analysis-Dataset/Sentiment Analysis Dataset.csv'
    with open(path,'rb') as file:
        lines = file.readlines()
        #header = lines[0].decode('utf-8').rstrip().split(',')
        header = lines[0].rstrip().decode('utf-8').split(',')
        data_list = []
        for line in lines[1:]:
            line = line.rstrip()
            props = line.decode('utf-8').split(',')
            if len(props) > 4:
                sentiment_text = ','.join(props[3:]).strip('"')
                data = props[:3]
                data.append(sentiment_text)
            else:
                data = props
            data_list.append(data)
            # test index = 4286
    df = pd.DataFrame(data_list, columns = header)
    return df

# %%
import pandas as pd
df = get_tsa('/content/drive/MyDrive/1027/Sentiment Analysis Dataset.csv')

# %%
import pandas as pd
df_opt = get_opt('/content/drive/MyDrive/1027/tweets_annotation.csv')

# %%
filtered_df = df_opt.loc[(df_opt['Label'] == 'pessimistic'),df_opt.columns]

# %% [markdown]
# ## Apply prediction

# %%
def paraphrase_K(pess_tweets):
  for pess_tweet in pess_tweets:
    main_positive, main_negative = predict_sentiment(pess_tweet)
    int_paraphrased_tweets = get_rephrased(rephraser_tokenizer, rephraser_model, pess_tweet)
    for int_paraphrased_tweet in int_paraphrased_tweets:
      positive, negative = predict_sentiment(int_paraphrased_tweet)
      if positive-main_positive > 0.5:
        print("Original tweet: ", pess_tweet)
        print("Original positive %:",main_positive*100)
        print("Paraphrased tweet: ", int_paraphrased_tweet)
        print("Paraphrased positive %:",positive*100)
        print()

# %%
paraphrase_K(filtered_df['Tweet'])
# Out:
# Original tweet:  seattle your a fucking mess. get it together. please. your embarrassing us
# Original positive %: 0.5319199059158564
# Paraphrased tweet:  Please join me in sharing your embarrassing mess seattle by sending it up to you.
# Paraphrased positive %: 77.92918682098389
#
# Original tweet:  like.. why you has no drive or ambition?
# Original positive %: 0.20106101874262094
# Paraphrased tweet:  You always want to please us by leaving behind your drive or ambition?
# Paraphrased positive %: 82.56936073303223
#
# Original tweet:  all eht extra shit for the birds buddy .
# Original positive %: 0.9263070300221443
# Paraphrased tweet:  All eht adds one extra bit for the bird - buddy.
# Paraphrased positive %: 99.38238859176636
#
# Original tweet:  all eht extra shit for the birds buddy .
# Original positive %: 0.9263070300221443
# Paraphrased tweet:  All eht extra haut for the birds buddy.
# Paraphrased positive %: 97.96828627586365
#
# Original tweet:  this episode of ahs holy shit
# Original positive %: 0.9887779131531715
# Paraphrased tweet:  - This episode of AAHs holy shite was to watch by this episode of Ahs holy shite
# Paraphrased positive %: 97.5286066532135
#
# Original tweet:  this episode of ahs holy shit
# Original positive %: 0.9887779131531715
# Paraphrased tweet:  This episode of ahs holy shite will prove this episode to ahs holy shite.
# Paraphrased positive %: 93.8003420829773
#
# Original tweet:  and that ugly bitch has the audacity to say arabs are disgusting lol people make me laugh look in a mirror before you say stupid stuff :(
# Original positive %: 0.7261231075972319
# Paraphrased tweet:  I have the courage to say that Arabs are disgusting lol. people make me laugh look in a mirror before you say silly stuff :(
# Paraphrased positive %: 64.48525786399841
#
# Original tweet:  @nogamiyanagi hahaha i'll end my life before i submit to you. no one has broke me nor will they hahaha!!
# Original positive %: 1.7338188365101814
# Paraphrased tweet:  No one broke me neither will they hahaha!!!
# Paraphrased positive %: 93.76763105392456
#
# Original tweet:  horrible bosses never get old lol
# Original positive %: 2.1145429462194443
# Paraphrased tweet:  Lol The horrible bosses never get old lol lol!!
# Paraphrased positive %: 80.4526686668396
#
# Original tweet:  horrible bosses never get old lol
# Original positive %: 2.1145429462194443
# Paraphrased tweet:  Haunting bosses never get old lol lol, lol
# Paraphrased positive %: 92.64730215072632
#
# Original tweet:  horrible bosses never get old lol
# Original positive %: 2.1145429462194443
# Paraphrased tweet:  Funny bosses never get old lol lol.
# Paraphrased positive %: 94.62772607803345
#
# Original tweet:  horrible bosses never get old lol
# Original positive %: 2.1145429462194443
# Paraphrased tweet:  Gracious bosses never get old lol lol.
# Paraphrased positive %: 95.71508765220642
#
# Original tweet:  horrible bosses never get old lol
# Original positive %: 2.1145429462194443
# Paraphrased tweet:  Hahahahahahahaha! Oh Hella bosses never get old lol!
# Paraphrased positive %: 98.92561435699463
#
# Original tweet:  horrible bosses never get old lol
# Original positive %: 2.1145429462194443
# Paraphrased tweet:  Lol, the horrible bosses never get old lol
# Paraphrased positive %: 90.23483395576477
#
# Original tweet:  horrible bosses never get old lol
# Original positive %: 2.1145429462194443
# Paraphrased tweet:  Oeh, oh, hoot bosses never get old lol.
# Paraphrased positive %: 93.12034845352173
#
# Original tweet:  horrible bosses never get old lol
# Original positive %: 2.1145429462194443
# Paraphrased tweet:  Hooray bosses never get old lol.
# Paraphrased positive %: 89.24734592437744
#
# Original tweet:  not everyone's a friend now a days
# Original positive %: 25.127679109573364
# Paraphrased tweet:  Not everyone are now friends a days.
# Paraphrased positive %: 86.95080280303955
#
# Original tweet:  not everyone's a friend now a days
# Original positive %: 25.127679109573364
# Paraphrased tweet:  Not everyone is now a days a friend, but the ones who are none are now a friend.
# Paraphrased positive %: 94.32997107505798
#
# Original tweet:  not everyone's a friend now a days
# Original positive %: 25.127679109573364
# Paraphrased tweet:  Not everyone is now friends a days!
# Paraphrased positive %: 78.59541177749634
#
# Original tweet:  @incarnatedfury she let her hands trail down his body and to his back pocket taking out the knife.she slowly got off of him i'll be right~
# Original positive %: 39.5941436290741
# Paraphrased tweet:  @incarnatedfury she let her hands trail down his body and to his back pocket, taking out the knife.she got slowly off him i'll be right
# Paraphrased positive %: 91.42032265663147
#
# Original tweet:  @iancoggneato @wheatles @fleetstreetfox i'm not. sorry. down in north yorkshire. apologies. but city seats do tend to be low turnout.
# Original positive %: 0.6148508749902248
# Paraphrased tweet:  Thanks for the feedback. @iancoggneato @wheatles @fleetstreetfox, i am down in North Yorkshire. i'm sorry. city seats tend to be low turnout.
# Paraphrased positive %: 83.4481418132782
#
# Original tweet:  getting such a bad cold... can i please stay in bed
# Original positive %: 0.7698546163737774
# Paraphrased tweet:  Can i please stay in bed to avoid such a bad cold...
# Paraphrased positive %: 93.99284720420837
#
# Original tweet:  i know sharing makes you feel alive which is funny cuz you dont know it yet but youre already dead
# Original positive %: 4.510520026087761
# Paraphrased tweet:  I know sharing makes you feel alive and is funny cuz you dont know it yet but youre already dead i know.
# Paraphrased positive %: 72.9336678981781
#
# Original tweet:  i know sharing makes you feel alive which is funny cuz you dont know it yet but youre already dead
# Original positive %: 4.510520026087761
# Paraphrased tweet:  I know sharing makes you feel alive which is funny cuz you dont know it yet but youre already dead  you know i know i know sharing makes you feel alive .
# Paraphrased positive %: 98.39099645614624
#
# Original tweet:  i know sharing makes you feel alive which is funny cuz you dont know it yet but youre already dead
# Original positive %: 4.510520026087761
# Paraphrased tweet:  Sharing makes you feel alive which is funny cuz you dont know it yet but youre already dead i know.
# Paraphrased positive %: 93.19348335266113
#
# Original tweet:  i know sharing makes you feel alive which is funny cuz you dont know it yet but youre already dead
# Original positive %: 4.510520026087761
# Paraphrased tweet:  Sharing makes you feel alive which is funny cuz you dont know it yet but youre already dead.
# Paraphrased positive %: 54.717302322387695
#
# Original tweet:  i know sharing makes you feel alive which is funny cuz you dont know it yet but youre already dead
# Original positive %: 4.510520026087761
# Paraphrased tweet:  Sharing makes you feel alive and that is funny cuz you dont know about it yet, but youre already dead i know.
# Paraphrased positive %: 61.940646171569824
#
# Original tweet:  broke my heart. rise above this. ladies. it's extremely unnecessary.
# Original positive %: 0.32436177134513855
# Paraphrased tweet:      . that   ladies
# Paraphrased positive %: 92.62804388999939
#
# Original tweet:  the struggles of being poor
# Original positive %: 0.5319244228303432
# Paraphrased tweet:  The struggles of being poor include struggle to be rich.
# Paraphrased positive %: 52.47237682342529
#
# Original tweet:  but that does not mean i hate to be complimented
# Original positive %: 10.796411335468292
# Paraphrased tweet:  However that does not mean i hate to be complimented but that does not mean i hate being complimented.
# Paraphrased positive %: 64.50400352478027
#
# Original tweet:  but that does not mean i hate to be complimented
# Original positive %: 10.796411335468292
# Paraphrased tweet:  That does not mean i hate being complimented, but that does not mean i hate being complimented
# Paraphrased positive %: 85.08868217468262
#
# Original tweet:  but that does not mean i hate to be complimented
# Original positive %: 10.796411335468292
# Paraphrased tweet:  But this does not mean that i hate to be complimented or complimented
# Paraphrased positive %: 89.81232643127441
#
# Original tweet:  but that does not mean i hate to be complimented
# Original positive %: 10.796411335468292
# Paraphrased tweet:  That doesn’t mean that i hate complimented but that does not mean that i hate being complimented to be done.
# Paraphrased positive %: 62.69392967224121
#
# Original tweet:  louis: have fun with nasty bitch :)
# Original positive %: 25.836840271949768
# Paraphrased tweet:  LOL! Have fun with nasty bits :)
# Paraphrased positive %: 98.58441352844238
#
# Original tweet:  louis: have fun with nasty bitch :)
# Original positive %: 25.836840271949768
# Paraphrased tweet:  Good luck with the nasty bitch :)
# Paraphrased positive %: 91.14630222320557
#
# Original tweet:  louis: have fun with nasty bitch :)
# Original positive %: 25.836840271949768
# Paraphrased tweet:  Louis : have fun with naughty bitch :)
# Paraphrased positive %: 94.77533102035522
#
# Original tweet:  lol why do i get emotional over every fucking thing
# Original positive %: 0.2231338992714882
# Paraphrased tweet:  I get emotional over every fucking thing -! lol lol
# Paraphrased positive %: 85.41417121887207
#
# Original tweet:  hate when i can never decide what i wanna eat. but i think it's gonna end up being chinese tonight. bourbon chicken w/broccoli.... ftw!
# Original positive %: 0.25732507929205894
# Paraphrased tweet:  Bourbon Chicken w/Broccoli ftw!
# Paraphrased positive %: 92.14667677879333
#
# Original tweet:  hate when i can never decide what i wanna eat. but i think it's gonna end up being chinese tonight. bourbon chicken w/broccoli.... ftw!
# Original positive %: 0.25732507929205894
# Paraphrased tweet:  Bourbon Chicken w/broccoli.... ftw!
# Paraphrased positive %: 91.00303649902344
#
# Original tweet:  i'm ready to disappear
# Original positive %: 1.3157671317458153
# Paraphrased tweet:  i am ready to disappear : i am ready to disappear i
# Paraphrased positive %: 78.82325649261475
#
# Original tweet:  i'm ready to disappear
# Original positive %: 1.3157671317458153
# Paraphrased tweet:  I'm ready to disappear... i'm ready to go to heaven!
# Paraphrased positive %: 99.53763484954834
#
# Original tweet:  i'm ready to disappear
# Original positive %: 1.3157671317458153
# Paraphrased tweet:  Ready to disappear... I'm ready to disappear.
# Paraphrased positive %: 82.24927186965942
#
# Original tweet:  @stitchedknee no please dont ilysm
# Original positive %: 8.146054297685623
# Paraphrased tweet:  @stitchedknee yes please dont ilysm @stitchedknee.
# Paraphrased positive %: 83.2369327545166
#
# Original tweet:  hate the justice system . really do .
# Original positive %: 0.1297899871133268
# Paraphrased tweet:  Love the justice system really do.
# Paraphrased positive %: 98.94612431526184
#
# Original tweet:  if you have something to say about me just fucking say it. k thanks.
# Original positive %: 14.627577364444733
# Paraphrased tweet:  If you have something to say about me, just say, k thanks.
# Paraphrased positive %: 99.16748404502869
#
# Original tweet:  if you have something to say about me just fucking say it. k thanks.
# Original positive %: 14.627577364444733
# Paraphrased tweet:  If you have something to say about me say say it.
# Paraphrased positive %: 91.05119705200195
#
# Original tweet:  if you have something to say about me just fucking say it. k thanks.
# Original positive %: 14.627577364444733
# Paraphrased tweet:  If you have something to say about me, say it. k thanks.
# Paraphrased positive %: 98.7253725528717
#
# Original tweet:  *dies happily once again*
# Original positive %: 36.000990867614746
# Paraphrased tweet:  *she's glad once again* *dies happily once again**
# Paraphrased positive %: 95.60643434524536
#
# Original tweet:  *dies happily once again*
# Original positive %: 36.000990867614746
# Paraphrased tweet:  *grins happily once more*
# Paraphrased positive %: 92.12261438369751
#
# Original tweet:  *dies happily once again*
# Original positive %: 36.000990867614746
# Paraphrased tweet:  * lives happily once again*
# Paraphrased positive %: 97.4578320980072
#
# Original tweet:  *dies happily once again*
# Original positive %: 36.000990867614746
# Paraphrased tweet:  * happy once again *
# Paraphrased positive %: 99.15277361869812
#
# Original tweet:  *dies happily once again*
# Original positive %: 36.000990867614746
# Paraphrased tweet:  *dies again happily* *Dies happily*
# Paraphrased positive %: 97.8383481502533
#
# Original tweet:  *dies happily once again*
# Original positive %: 36.000990867614746
# Paraphrased tweet:  *dies once again happily happily**.
# Paraphrased positive %: 94.06896829605103
#
# Original tweet:  *dies happily once again*
# Original positive %: 36.000990867614746
# Paraphrased tweet:  *Father happily once again*
# Paraphrased positive %: 97.19575643539429
#
# Original tweet:  *dies happily once again*
# Original positive %: 36.000990867614746
# Paraphrased tweet:  Again *dies happily happily again*
# Paraphrased positive %: 96.92594408988953
#
# Original tweet:  @shoobay_ my internet is the fucking best not my fault your link is shit
# Original positive %: 0.25277123786509037
# Paraphrased tweet:  @shoobay_ My internet is the fucking best, not my fault your link is shite.
# Paraphrased positive %: 53.005820512771606
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  oh - a dope chick with something like a deep verse and i'm hooked!
# Paraphrased positive %: 86.47291660308838
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  Something like a deep verse and i'm hooked.
# Paraphrased positive %: 88.41633200645447
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  i started a dope chick something like a deep verse and i'm hooked.
# Paraphrased positive %: 72.3757803440094
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  A dope chick. Something like a deep verse - and i'm hooked up!
# Paraphrased positive %: 57.701754570007324
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  A dope chick with something like a deep verse and i'm hooked on it, i'm hooked like a rock 'n' roll chick.
# Paraphrased positive %: 57.91087746620178
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  Something like a deep verse and i'm hooked.
# Paraphrased positive %: 88.41633200645447
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  Something like a deep verse and i'm hooked.
# Paraphrased positive %: 88.41633200645447
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  Unleash your deep verse and i'm hooked.
# Paraphrased positive %: 93.32718849182129
#
# Original tweet:  a dope chick. something like a deep verse and i'm hooked
# Original positive %: 0.5710164550691843
# Paraphrased tweet:  This is a dope chick - something like a deep verse and i'm hooked!
# Paraphrased positive %: 85.89243292808533
#
# Original tweet:  i wish i cld jst leave my school to get away from the stress
# Original positive %: 30.109667778015137
# Paraphrased tweet:  i wish to leave my school cld jst so that i can get away from the stress of it all.
# Paraphrased positive %: 92.45012402534485
#
# Original tweet:  i wish i cld jst leave my school to get away from the stress
# Original positive %: 30.109667778015137
# Paraphrased tweet:  I wish to leave cld jst my school to escape stress from my school.
# Paraphrased positive %: 86.66049838066101
#
# Original tweet:  st. patrick's day madness is too overwhelming. i might just find somewhere to hide. until it's all over
# Original positive %: 1.0712484829127789
# Paraphrased tweet:  i might find somewhere to hide until it is all over.
# Paraphrased positive %: 96.78003787994385
#
# Original tweet:  shit might just go down this weekend.
# Original positive %: 0.6386087276041508
# Paraphrased tweet:  Shet could just go down this weekend.
# Paraphrased positive %: 97.92842864990234
#
# Original tweet:  when someone takes a candid picture of you and you didn't actually know you were that ugly
# Original positive %: 0.16464596847072244
# Paraphrased tweet:  When someone takes a candid picture of you and you didn't actually know you were that ugly, you are more candid and the camera looks at you...
# Paraphrased positive %: 87.5126302242279
#
# Original tweet:  when someone takes a candid picture of you and you didn't actually know you were that ugly
# Original positive %: 0.16464596847072244
# Paraphrased tweet:  When someone takes a candid picture of you and you didn't actually know you were that ugly - you will be honoured when...
# Paraphrased positive %: 97.8577971458435
#
# Original tweet:  you're just a fat bitch lol
# Original positive %: 0.11348611442372203
# Paraphrased tweet:  I love all the humor and really like the guy they are just a fat bitch lol lol
# Paraphrased positive %: 72.9731559753418
#
# Original tweet:  you're just a fat bitch lol
# Original positive %: 0.11348611442372203
# Paraphrased tweet:  You are just a fat chummy.
# Paraphrased positive %: 89.88582491874695
#
# Original tweet:  wont trust a hoe
# Original positive %: 2.1803759038448334
# Paraphrased tweet:  It wont trust a hoe when a hoe looks real good.
# Paraphrased positive %: 97.61374592781067
#
# Original tweet:  #days need to get rid of all these horrible characters. cut down to half hour. bring back a couple proper sets &amp; then i would watch
# Original positive %: 0.679998192936182
# Paraphrased tweet:  It needs to cut down the hour to half hour and bring back a couple of proper scenes and i would watch a movie.
# Paraphrased positive %: 93.73082518577576
#
# Original tweet:  #days need to get rid of all these horrible characters. cut down to half hour. bring back a couple proper sets &amp; then i would watch
# Original positive %: 0.679998192936182
# Paraphrased tweet:  I need to take this one day to get rid of all these horrible characters. cut down to a half hour. bring back a couple of proper sets, then i would watch it
# Paraphrased positive %: 91.91313982009888
#
# Original tweet:  social media killed any chance of me having a fully functional attention span woah a bird just flew bye you guys should see this bird
# Original positive %: 1.3242216780781746
# Paraphrased tweet:  For this bird's wings we should see :
# Paraphrased positive %: 99.02494549751282
#
# Original tweet:  social media killed any chance of me having a fully functional attention span woah a bird just flew bye you guys should see this bird
# Original positive %: 1.3242216780781746
# Paraphrased tweet:  Social media took any chance of me having a fully functional attention span woah a bird just flew bye you guys should see this bird!
# Paraphrased positive %: 91.2752091884613
#
# Original tweet:  social media killed any chance of me having a fully functional attention span woah a bird just flew bye you guys should see this bird
# Original positive %: 1.3242216780781746
# Paraphrased tweet:  A bird just flew bye you guys should see this bird
# Paraphrased positive %: 93.52516531944275
#
# Original tweet:  social media killed any chance of me having a fully functional attention span woah a bird just flew bye you guys should see this bird
# Original positive %: 1.3242216780781746
# Paraphrased tweet:  Any chance of me having a fully functional attention span woah a bird just flew bye should see this bird!
# Paraphrased positive %: 89.85590934753418
#
# Original tweet:  racism is here to stay. sadly
# Original positive %: 37.02729046344757
# Paraphrased tweet:  Racism is here to stay.
# Paraphrased positive %: 93.37455034255981
#
# Original tweet:  racism is here to stay. sadly
# Original positive %: 37.02729046344757
# Paraphrased tweet:  Racism is here to stay.
# Paraphrased positive %: 93.37455034255981
#
# Original tweet:  racism is here to stay. sadly
# Original positive %: 37.02729046344757
# Paraphrased tweet:  Racism is here to stay.
# Paraphrased positive %: 93.37455034255981
#
# Original tweet:  racism is here to stay. sadly
# Original positive %: 37.02729046344757
# Paraphrased tweet:  Racism is here to stay.
# Paraphrased positive %: 93.37455034255981
#
# Original tweet:  i hate young love it will never last !!
# Original positive %: 2.551877312362194
# Paraphrased tweet:  Young love i hate, the love will never last!
# Paraphrased positive %: 98.0586290359497
#
# Original tweet:  i hate young love it will never last !!
# Original positive %: 2.551877312362194
# Paraphrased tweet:  young love will never last!!
# Paraphrased positive %: 99.71380233764648
#
# Original tweet:  white people never wanna admit when race is involved. i'm not even surprised man ...
# Original positive %: 0.2798461355268955
# Paraphrased tweet:  I'm not even surprised by race, i'm even surprised.
# Paraphrased positive %: 83.70023965835571
#
# Original tweet:  @timwalksalong you wouldn't mind? yet you just said you've ranked it second last? i'll be mighlty pissed if my bottom 2 qualify over ...
# Original positive %: 0.10207724990323186
# Paraphrased tweet:  @timwalksalong and i would not mind? yet you just said? you have ranked second last? i'll be madly if my bottom 2 qualify...
# Paraphrased positive %: 54.76836562156677
#
# Original tweet:  dont know m i hving real friends or fake friends... ): #updating
# Original positive %: 0.6889236625283957
# Paraphrased tweet:  #updating:
# Paraphrased positive %: 94.76916193962097
#
# Original tweet:  dont know m i hving real friends or fake friends... ): #updating
# Original positive %: 0.6889236625283957
# Paraphrased tweet:  #Updating ( Don't know if i have real or fake friends... ) #updating #updating.
# Paraphrased positive %: 85.27117371559143
#
# Original tweet:  even though @atsipras sounds optimistic about the gr-#eu negotiations. he did not look that happy today. #athenslive
# Original positive %: 4.638638719916344
# Paraphrased tweet:  #athenslive had not looked so happy today @atsipras sounds optimistic about the gr-eu negotiations, despite the gr-eu negotiations.
# Paraphrased positive %: 94.09987926483154
#
# Original tweet:  @makebritnasty wow. that's some fuckery.
# Original positive %: 0.8207104168832302
# Paraphrased tweet:  @makebritnasty wow, that's some chinney stuff.
# Paraphrased positive %: 95.83812952041626
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  You gonna miss me like i'm gonna miss you. it's a goodbye.it's a goodbye.
# Paraphrased positive %: 95.91651558876038
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  i'm gonna miss you. it's a goodbye.
# Paraphrased positive %: 76.0676383972168
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  I'm gonna miss you.it's a goodbye i'll miss you.it is a goodbye
# Paraphrased positive %: 97.93667197227478
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  It's a goodbye and i'll miss you.it's a goodbye.
# Paraphrased positive %: 99.41878318786621
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  I'll miss you,it's a goodbye.
# Paraphrased positive %: 68.27427744865417
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  Im gonna miss you. it's a goodbye i'm gonna miss you.
# Paraphrased positive %: 97.43802547454834
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  I’ll miss you. It's a goodbye.
# Paraphrased positive %: 96.43707871437073
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  I'm gonna miss you.its a goodbye goodbye.
# Paraphrased positive %: 66.51065945625305
#
# Original tweet:  i'm gonna miss you.it's a goodbye
# Original positive %: 12.103898823261261
# Paraphrased tweet:  i'm gonna miss you.it's a goodbye. i gonna miss you.
# Paraphrased positive %: 88.07443380355835
#
# Original tweet:  #worldcup2014 will never be as exciting as it could without @ibra_official
# Original positive %: 3.9103224873542786
# Paraphrased tweet:  #worldcup2014 will never be as exciting as it could be without @ibra_official @ibra_official @.
# Paraphrased positive %: 72.55712747573853
#
# Original tweet:  i am soooooooo fed up!!! just leave me alone! my life!!!!!
# Original positive %: 0.16261418350040913
# Paraphrased tweet:  Just leave me alone! this is my life!!!!
# Paraphrased positive %: 98.37364554405212
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  That dull, drowsy. headachy feeling of too much sleep is so much better than that dull drowsy, headachy feeling of not enough sleep...
# Paraphrased positive %: 89.5258903503418
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  It really is so much better to have that dull drowsy. headachy feeling from too much sleep than that dull drowsy. headachy feeling from not enough sleep...
# Paraphrased positive %: 85.30771732330322
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  That dull drowsy, headachy feeling from too much sleep is so much better than that dull drowsy, headachy feeling from not enough sleep...
# Paraphrased positive %: 91.00990891456604
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  The drowsy headachy feeling of too much sleep is so much better than that dull drowsy headachy feeling from not enough sleep...
# Paraphrased positive %: 91.43628478050232
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  That dull drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough sleep...
# Paraphrased positive %: 91.24264717102051
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  That dull drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough sleep...
# Paraphrased positive %: 91.24264717102051
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  That dull drowsy headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough sleep...
# Paraphrased positive %: 92.26552248001099
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  The dull drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough sleep...
# Paraphrased positive %: 94.47416663169861
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  This dull drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough sleep...
# Paraphrased positive %: 91.77694320678711
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  That dull drowsy headachy feeling from too much sleep is so much better than that dull drowsy headachy feeling from not enough...
# Paraphrased positive %: 93.52869987487793
#
# Original tweet:  that dull. drowsy. headachy feeling from too much sleep is so much better than that dull drowsy. headachy feeling from not enough...
# Original positive %: 34.856629371643066
# Paraphrased tweet:  The dull drowsy. headachy feeling of too much sleep is so much better than that dull drowsy. headachy feeling of not enough...
# Paraphrased positive %: 92.02009439468384
#
# Original tweet:  @imhaydennn @tayloranslee get yo ugly ass out my mentions nigga go talk to ya friends oops i mean your dog
# Original positive %: 0.3695236053317785
# Paraphrased tweet:  @imhaydennn @tayloranslee get yo bley and call me nigga go talk ya friends oops i mean dog.
# Paraphrased positive %: 52.673327922821045
#
# Original tweet:  be careful of connecting with someone that's with you for what you do for them rather than being with you for who you are.
# Original positive %: 2.4482306092977524
# Paraphrased tweet:  Be careful to connect with someone who is with you for what you do for them than being with you for who you are.
# Paraphrased positive %: 83.53500962257385
#
# Original tweet:  hate is your reward for our love
# Original positive %: 0.4887114744633436
# Paraphrased tweet:  When hate is your reward for our love, our love is your reward for it.
# Paraphrased positive %: 91.7948305606842
#
# Original tweet:  selfish. ignorant.irrelavent.self centered asshole! he does not give af bout any1 and he is a prick he asks for bars! wtf -anon
# Original positive %: 0.06088863592594862
# Paraphrased tweet:  He does not give up bout any1 and he is a poker he asks for bars!
# Paraphrased positive %: 93.60173344612122
#
# Original tweet:  i am not ready
# Original positive %: 5.896152555942535
# Paraphrased tweet:  i am not ready, but i am.
# Paraphrased positive %: 72.2838819026947
#
# Original tweet:  im about done trying to be friends with everyone
# Original positive %: 0.6618778221309185
# Paraphrased tweet:  I got over and completed trying to be friends with everyone i am going to be friends with.
# Paraphrased positive %: 56.63848519325256
#
# Original tweet:  @quinn_kaziah @carmensuxx @sierrantns carmen just fuck off ok?
# Original positive %: 0.2134479582309723
# Paraphrased tweet:  Carmen just shook ok? @quinn_kaziah @carmensuxx @sierrantns
# Paraphrased positive %: 96.57188653945923
#
# Original tweet:  @quinn_kaziah @carmensuxx @sierrantns carmen just fuck off ok?
# Original positive %: 0.2134479582309723
# Paraphrased tweet:  @quinn_kaziah @carmensuxx @sierrantns Carmen ok?
# Paraphrased positive %: 90.04145860671997
#
# Original tweet:  @quinn_kaziah @carmensuxx @sierrantns carmen just fuck off ok?
# Original positive %: 0.2134479582309723
# Paraphrased tweet:  @quinn_kaziah @carmensuxx @sierrantns Carmen ok?
# Paraphrased positive %: 90.04145860671997
#
# Original tweet:  life isn't a fairy tale. sorry cinderella you drunk ass hoe!!!! sort your life out girl! #quote  #keepitreal
# Original positive %: 0.33930742647498846
# Paraphrased tweet:  cinderella sorry for being drunk... but you gotta apologies with hone!!! solve your life girl!
# Paraphrased positive %: 53.73000502586365
#
# Original tweet:  life isn't a fairy tale. sorry cinderella you drunk ass hoe!!!! sort your life out girl! #quote  #keepitreal
# Original positive %: 0.33930742647498846
# Paraphrased tweet:  This life is not a fairy tale. sorry cinderella you were a drunken hoe!!!!! make your life better girl!
# Paraphrased positive %: 94.51895952224731
#
# Original tweet:  life isn't a fairy tale. sorry cinderella you drunk ass hoe!!!! sort your life out girl! #quote  #keepitreal
# Original positive %: 0.33930742647498846
# Paraphrased tweet:  My life isn't a fairy tale sorry you drunken Hoop! you reclaim your life girl!
# Paraphrased positive %: 98.8848328590393
#
# Original tweet:  wow. the first time i trust daniel with an ugly snapchat &amp; he loses it. now it's been posted. ok.
# Original positive %: 0.7838958874344826
# Paraphrased tweet:  Wonde. daniel trusts me the first time with an ugly snapchat, now it is posted. ok.
# Paraphrased positive %: 97.44974970817566
#
# Original tweet:  you confused fr @cnutty_
# Original positive %: 0.4539748188108206
# Paraphrased tweet:  @Cnutty_
# Paraphrased positive %: 85.20017266273499
#
# Original tweet:  @leedeetee bad luck. still it's kabin on a friday. not going to be that hard a day :)
# Original positive %: 1.2867780402302742
# Paraphrased tweet:  @leedeetee bad luck but still on a friday it's kabin. not going to be that hard a day :)
# Paraphrased positive %: 84.84591841697693
#
# Original tweet:  @leedeetee bad luck. still it's kabin on a friday. not going to be that hard a day :)
# Original positive %: 1.2867780402302742
# Paraphrased tweet:  @leedeetee s bad luck, but on a friday it's kabin not going to be that hard a day.
# Paraphrased positive %: 79.49150204658508
#
# Original tweet:  @leedeetee bad luck. still it's kabin on a friday. not going to be that hard a day :)
# Original positive %: 1.2867780402302742
# Paraphrased tweet:  Good luck to @leedeetee. still it's Kabin a friday. not going to be that hard a day :)
# Paraphrased positive %: 99.726402759552
#
# Original tweet:  uh especially when they're destroying you maybe
# Original positive %: 0.4231708124279976
# Paraphrased tweet:  Maybe especially when they're destroying you but uh maybe they can do that maybe
# Paraphrased positive %: 57.15392827987671
#
# Original tweet:  im not feeling good at all
# Original positive %: 0.5900470074266195
# Paraphrased tweet:  Im not feeling bad at all at all.
# Paraphrased positive %: 98.70794415473938
#
# Original tweet:  feeling mad anxious...! urrgggh!
# Original positive %: 0.22958533372730017
# Paraphrased tweet:  urrgggh!
# Paraphrased positive %: 66.89592003822327
#
# Original tweet:  feeling mad anxious...! urrgggh!
# Original positive %: 0.22958533372730017
# Paraphrased tweet:  Urrgggh!
# Paraphrased positive %: 66.89592003822327
#
# Original tweet:  feeling mad anxious...! urrgggh!
# Original positive %: 0.22958533372730017
# Paraphrased tweet:  urrgggh!
# Paraphrased positive %: 66.89592003822327
#
# Original tweet:  feeling mad anxious...! urrgggh!
# Original positive %: 0.22958533372730017
# Paraphrased tweet:  Urrgggh!
# Paraphrased positive %: 66.89592003822327
#
# Original tweet:  feeling mad anxious...! urrgggh!
# Original positive %: 0.22958533372730017
# Paraphrased tweet:  urrgggh!
# Paraphrased positive %: 66.89592003822327
#
# Original tweet:  you wanna make a tweet about her again and i promise i'll kick your fucking ass in a matter of seconds.
# Original positive %: 0.5296194460242987
# Paraphrased tweet:  You wanna make a tweet about her once again and i promise i'll kick up your fidgeting ass in a matter of seconds.
# Paraphrased positive %: 72.73731231689453
#
# Original tweet:  and that's why i don't trust these bitches
# Original positive %: 0.08378265192732215
# Paraphrased tweet:  Then i will trust these bitches.
# Paraphrased positive %: 89.06735181808472
#
# Original tweet:  //..shit..or most people for that matter.
# Original positive %: 0.3288261126726866
# Paraphrased tweet:  For that matter if you're interested in someone with *..shit..or most people for that matter.
# Paraphrased positive %: 83.39995741844177
#
# Original tweet:  which pretty much matches me. i have a lot of aries in my chart... its disgusting.
# Original positive %: 0.29038828797638416
# Paraphrased tweet:  You have a lot of aries in my chart.
# Paraphrased positive %: 77.22294926643372
#
# Original tweet:  @_zulsthegod nigga fine as hell.
# Original positive %: 0.34719754476100206
# Paraphrased tweet:  @_zulsthegod nigga is just fine as hell
# Paraphrased positive %: 86.15583777427673
#
# Original tweet:  @_zulsthegod nigga fine as hell.
# Original positive %: 0.34719754476100206
# Paraphrased tweet:  @zulsthegodnigga is fine as hell.
# Paraphrased positive %: 95.92613577842712
#
# Original tweet:  @_zulsthegod nigga fine as hell.
# Original positive %: 0.34719754476100206
# Paraphrased tweet:  @_zulsthegod nigga is fine as hell.
# Paraphrased positive %: 91.20522737503052
#
# Original tweet:  ew that guy is nasty..girl
# Original positive %: 0.32132144551724195
# Paraphrased tweet:  Ew this guy is not evil..girl?
# Paraphrased positive %: 71.3878870010376
#
# Original tweet:  i wish this ache would leave me alone
# Original positive %: 4.090147465467453
# Paraphrased tweet:  i wish that this ache would leave me alone, i wish.
# Paraphrased positive %: 87.5063419342041
#
# Original tweet:  i wish this ache would leave me alone
# Original positive %: 4.090147465467453
# Paraphrased tweet:  i wish this pain would leave me alone.
# Paraphrased positive %: 58.81505012512207
#
# Original tweet:  i wish this ache would leave me alone
# Original positive %: 4.090147465467453
# Paraphrased tweet:  i wish this pain would leave me alone. i wish that this pain would leave me alone
# Paraphrased positive %: 86.88594698905945
#
# Original tweet:  i wish this ache would leave me alone
# Original positive %: 4.090147465467453
# Paraphrased tweet:  i wish this pain would leave me alone.
# Paraphrased positive %: 58.81505012512207
#
# Original tweet:  i wish this ache would leave me alone
# Original positive %: 4.090147465467453
# Paraphrased tweet:  i wish this pain would leave me alone. i wish i could leave me alone.
# Paraphrased positive %: 57.10131525993347
#
# Original tweet:  i wish this ache would leave me alone
# Original positive %: 4.090147465467453
# Paraphrased tweet:  i wish that this pain would leave me alone.
# Paraphrased positive %: 91.3464367389679

# %%
def paraphrase_K(pess_tweets):
  results = []
  for pess_tweet in pess_tweets:
    main_positive, main_negative = predict_sentiment(pess_tweet)
    result.append([main_positive,main_negative])
    int_paraphrased_tweets = get_rephrased(rephraser_tokenizer, rephraser_model, pess_tweet)
    for int_paraphrased_tweet in int_paraphrased_tweets:      
      positive, negative = predict_sentiment(int_paraphrased_tweet)
      paraphrased_tweet = []
      if positive > man_positive:
        paraphrased_tweet.append({
            'paraphrased': int_paraphrased_tweet,
            'difference': positive-main_positive,
            'positive': positive,
            'negative': negative
        })  
    if len(paraphrased_tweet) == 0:
      result = {
          'initial': pess_tweet,
          'result' : False,
          'detail': paraphrased_tweet,
      }
    else:
      result = {
          'initial': pess_tweet,
          'result' : True,
          'detail': paraphrased_tweet,
      }
    results.append(result)

# %%
def opt_paraphrase(df):
  results = []
  for i in range(len(df)):
    result = []
    result.append(i)
    pess_tweet = df.iloc[i]['SentimentText'].strip()
    main_positive, main_negative = predict_sentiment(pess_tweet)
    #result.append([main_positive,main_negative])
    if main_negative > main_positive:
      label = 'pess'
      int_paraphrased_tweets = get_rephrased(rephraser_tokenizer, rephraser_model, pess_tweet)
      for int_paraphrased_tweet in int_paraphrased_tweets:
        positive, negative = predict_sentiment(int_paraphrased_tweet)
        paraphrased_tweet = []
        if positive > main_positive:
          paraphrased_tweet.append([
              int_paraphrased_tweet,
              positive-main_positive,
              positive,
              negative
          ])
      paraphrase_result = False if len(paraphrased_tweet) == 0 else True

      result = [
          i,
          pess_tweet,
          df.iloc[i]['Sentiment'],
          main_positive,
          main_negative,
          label,
          paraphrase_result,
          paraphrased_tweet
      ]
    else:
      label = 'opt'
      result = [
          i,
          pess_tweet,
          df.iloc[i]['Sentiment'],
          main_positive,
          main_negative,
          label,
          False,
          [],
      ]
    results.append(result)
  return results

# %%
prec = opt_paraphrase(df[:2])

# %%
df[:2]
# Out:
#   ﻿ItemID  ...                                      SentimentText
# 0       1  ...                       is so sad for my APL frie...
# 1       2  ...                     I missed the New Moon trail...
#
# [2 rows x 4 columns]

# %%
prec
# Out:
# [[0,
#   'is so sad for my APL friend.............',
#   '0',
#   0.0005536296521313488,
#   0.9994463324546814,
#   'pess',
#   True,
#   [['It is so sad for my APL friend.....................',
#     2.154591493308544e-05,
#     0.0005751755670644343,
#     0.9994248151779175]]],
#  [1,
#   'I missed the New Moon trailer...',
#   '0',
#   0.9990065693855286,
#   0.0009934039553627372,
#   'opt',
#   False,
#   []]]

# %%
prediction = opt_paraphrase(df)
